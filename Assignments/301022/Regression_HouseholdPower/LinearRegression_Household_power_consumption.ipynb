# %% [markdown]
# **Linear Regression**

# %%
# Fetching data from MongoDB

# %% [markdown]
# # Fetching model from database

# %%
from pymongo import MongoClient
import pickle
from bson.objectid import ObjectId

# %%
client = MongoClient("mongodb+srv://dev_user:1Cand0thi5@cluster0.34cpv.mongodb.net/?retryWrites=true&w=majority")

# %%
try:
  document = client['ml_models']
  collection = document['hhpc_pp']
  # find_response = collection.find_one({ "_id": ObjectId(inserted_response.inserted_id) })
  find_response = collection.find_one({"tag": "HPC_PP_M"})
  pickle_model = pickle.loads(find_response['hhpc_model'])
  X_train = pickle_model["X_train_ft"]
  X_test = pickle_model["X_test_t"]
  y_train = pickle_model["y_train"]
  y_test = pickle_model["y_test"]
  dependent_features = pickle_model["dependent_features"]
except Exception as e:
  print(e)
  raise Exception("Unable process into the store")

# %% [markdown]
# # LinearRegression - Model Training

# %%
from sklearn.linear_model import LinearRegression

# %%
ln_r = LinearRegression()

# %%
ln_r.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # Coefficient & Intercept

# %%
print("# | Feature | Coefficient |")
print("_" * 50)
for index, dependent_feature in enumerate(dependent_features):
  print(index+1, "|", dependent_feature, "|", ln_r.coef_[index])
# Out:
# # | Feature | Coefficient |
# __________________________________________________
# 1 | Global_active_power | 20.834777110468394
# 2 | Global_reactive_power | -0.33318463375310614
# 3 | Voltage | -0.26611953140834255
# 4 | Global_intensity | -9.77348745603618

# %%
print("Intercept:", ln_r.intercept_)
# Out:
# Intercept: 8.694450934579438

# %%
ln_r.score(X_test, y_test)
# Out:
# 0.7175854638257068

# %%
y_predict = ln_r.predict(X_test)

# %% [markdown]
# # Prediction visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(20, 8))
sns.scatterplot(x=y_test, y=y_predict)

# %%
plt.figure(figsize=(20, 8))
sns.regplot(x=y_test, y=y_predict)

# %%
# Calculate residuals

residuals = y_test-y_predict

# %%
sns.displot(residuals, kind="kde")

# %%
plt.figure(figsize=(16, 8))
sns.scatterplot(x=y_predict, y=residuals)

# %% [markdown]
# # Cost function and performance metrics

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

# %%
MSE = mean_squared_error(y_test, y_predict)
MAE = mean_squared_error(y_test, y_predict)
print("Mean Squared Error", MSE)
print("Mean Absolute Error", MAE)
print("Root Mean Square Error", np.sqrt(MSE))
# Out:
# Mean Squared Error 46.08231988418242
# Mean Absolute Error 46.08231988418242
# Root Mean Square Error 6.788395972848256

# %%
score = r2_score(y_test, y_predict)
adj_score = 1 - (1-score)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)
print("R Squared: ", score)
print("Adjusted R Sqaured: ", adj_score)
# Out:
# R Squared:  0.7175854638257068
# Adjusted R Sqaured:  0.7175529612896066

# %% [markdown]
# **==================THE END==================**
